# %% [markdown]
# # Get to Know the Data

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# Read the dataset, convert to dataframe

# %%
isp = pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results.csv')

# %%
print(len(isp))
isp.head(3)
# Out:
# 208459
#       CAMIS                                     DBA       BORO  BUILDING  \
# 0  41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1  50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2  50139946                               CHEZ OMAR  Manhattan       394
#
#              STREET  ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0   NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1  STILLWELL AVENUE  11223.0  7182320055                 NaN      01/01/1900
# 2       WEST STREET  10014.0  9175606080                 NaN      01/01/1900
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
#
#                             VIOLATION DESCRIPTION   CRITICAL FLAG  SCORE  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
#
#   GRADE GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 0   NaN        NaN  11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN  11/12/2023                                    NaN
# 2   NaN        NaN  11/12/2023                                    NaN
#
#     Latitude  Longitude  Community Board  Council District  Census Tract  \
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
#
#          BIN           BBL   NTA  Location Point1
# 0        NaN  4.000000e+00   NaN              NaN
# 1  3176369.0  3.066430e+09  BK29              NaN
# 2  1011975.0  1.006360e+09  MN23              NaN

# %%
isp.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location Point1'],
#       dtype='object')

# %%
isp.dtypes
# Out:
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION       object
# INSPECTION DATE           object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# Latitude                 float64
# Longitude                float64
# Community Board          float64
# Council District         float64
# Census Tract             float64
# BIN                      float64
# BBL                      float64
# NTA                       object
# Location Point1          float64
# dtype: object

# %%
isp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208459 entries, 0 to 208458
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  208459 non-null  int64
#  1   DBA                    207872 non-null  object
#  2   BORO                   208459 non-null  object
#  3   BUILDING               208130 non-null  object
#  4   STREET                 208452 non-null  object
#  5   ZIPCODE                205775 non-null  float64
#  6   PHONE                  208451 non-null  object
#  7   CUISINE DESCRIPTION    206045 non-null  object
#  8   INSPECTION DATE        208459 non-null  object
#  9   ACTION                 206045 non-null  object
#  10  VIOLATION CODE         204901 non-null  object
#  11  VIOLATION DESCRIPTION  204901 non-null  object
#  12  CRITICAL FLAG          208459 non-null  object
#  13  SCORE                  198589 non-null  float64
#  14  GRADE                  102128 non-null  object
#  15  GRADE DATE             93505 non-null   object
#  16  RECORD DATE            208459 non-null  object
#  17  INSPECTION TYPE        206045 non-null  object
#  18  Latitude               208198 non-null  float64
#  19  Longitude              208198 non-null  float64
#  20  Community Board        205231 non-null  float64
#  21  Council District       205227 non-null  float64
#  22  Census Tract           205227 non-null  float64
#  23  BIN                    204252 non-null  float64
#  24  BBL                    207908 non-null  float64
#  25  NTA                    205231 non-null  object
#  26  Location Point1        0 non-null       float64
# dtypes: float64(10), int64(1), object(16)
# memory usage: 42.9+ MB

# %%
isp.describe()
# Out:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.084590e+05  205775.000000  198589.000000  208198.000000
# mean   4.755613e+07   10707.892723      22.791841      40.202806
# std    4.027041e+06     594.464550      17.533970       4.588820
# min    3.007544e+07    8512.000000       0.000000       0.000000
# 25%    4.164907e+07   10023.000000      11.000000      40.682779
# 50%    5.006713e+07   11101.000000      19.000000      40.730046
# 75%    5.010698e+07   11231.000000      30.000000      40.760941
# max    5.014427e+07   12345.000000     168.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  208198.000000    205231.000000     205227.000000  205227.000000
# mean      -72.990595       254.572219         20.843383   30087.219688
# std         8.330709       130.044844         15.835136   31612.998534
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988915       106.000000          4.000000    8000.000000
# 50%       -73.956446       302.000000         20.000000   17402.000000
# 75%       -73.896137       401.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL  Location Point1
# count  2.042520e+05  2.079080e+05              0.0
# mean   2.576378e+06  2.465193e+09              NaN
# std    1.346160e+06  1.336778e+09              NaN
# min    1.000000e+06  1.000000e+00              NaN
# 25%    1.051209e+06  1.010898e+09              NaN
# 50%    3.022022e+06  3.008010e+09              NaN
# 75%    4.006920e+06  4.004721e+09              NaN
# max    5.799501e+06  5.270001e+09              NaN

# %%
isp.tail(3)
# Out:
#            CAMIS                       DBA       BORO BUILDING  \
# 208456  50002491  AGORA TURKISH RESTAURANT  Manhattan     1565
# 208457  50115895              PAPA'S PIZZA   Brooklyn      187
# 208458  50051668      JOE & SAL'S PIZZERIA   Brooklyn      842
#
#                  STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 208456    SECOND AVENUE  10028.0  2127171220             Turkish
# 208457   BEDFORD AVENUE  11211.0  7187243651               Pizza
# 208458  FRANKLIN AVENUE  11225.0  7184848732               Pizza
#
#        INSPECTION DATE                                           ACTION  \
# 208456      03/22/2022  Violations were cited in the following area(s).
# 208457      10/18/2023  Violations were cited in the following area(s).
# 208458      05/02/2023  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 208456            08C  Pesticide use not in accordance with label or ...
# 208457            08A  Establishment is not free of harborage or cond...
# 208458            04A  Food Protection Certificate (FPC) not held by ...
#
#        CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 208456  Not Critical    0.0   NaN         NaN  11/12/2023
# 208457  Not Critical   39.0     Z  10/18/2023  11/12/2023
# 208458      Critical   46.0   NaN         NaN  11/12/2023
#
#                               INSPECTION TYPE   Latitude  Longitude  \
# 208456  Cycle Inspection / Initial Inspection  40.774846 -73.953959
# 208457       Cycle Inspection / Re-inspection  40.717675 -73.957876
# 208458  Cycle Inspection / Initial Inspection  40.669260 -73.958487
#
#         Community Board  Council District  Census Tract        BIN  \
# 208456            108.0               5.0       13800.0  1048567.0
# 208457            301.0              34.0       55300.0  3062093.0
# 208458            309.0              35.0       21300.0  3029694.0
#
#                  BBL   NTA  Location Point1
# 208456  1.015270e+09  MN32              NaN
# 208457  3.023280e+09  BK73              NaN
# 208458  3.011870e+09  BK63              NaN

# %% [markdown]
# NOTE: Establishments with inspection date of 1/1/1900 are new establishments that have not yet received an inspection.
#
# Q: *Why is this significant?*

# %%
isp['SCORE'].value_counts(dropna=False).sort_index().plot.bar(figsize=(24,8),x='Score',y='Frequency',title='Score Distribution')
# Out:
# <Axes: title={'center': 'Score Distribution'}>

# %% [markdown]
# Health Inspection Scores:
# 0-13 - A
# 14-27 - B
# 28+ - C
#
# Insights:
# -Many restaurants have scores of 12 and 13 -- just below the threshold to still have an "A" score

# %%
isp['GRADE'].value_counts(dropna=True).plot.bar(figsize=(24,8),x='Grade',y='Frequency',title='Rest Grades')
# Out:
# <Axes: title={'center': 'Rest Grades'}>

# %% [markdown]
# NOTE: Renaming Columns to a more analysis-friendly format.

# %%
new_col_list = []

for item in isp.columns:
    item = item.strip()
    item = item.replace(' ', '_')
    item = item.capitalize()
    new_col_list.append(item)

new_col_list
# Out:
# ['Camis',
#  'Dba',
#  'Boro',
#  'Building',
#  'Street',
#  'Zipcode',
#  'Phone',
#  'Cuisine_description',
#  'Inspection_date',
#  'Action',
#  'Violation_code',
#  'Violation_description',
#  'Critical_flag',
#  'Score',
#  'Grade',
#  'Grade_date',
#  'Record_date',
#  'Inspection_type',
#  'Latitude',
#  'Longitude',
#  'Community_board',
#  'Council_district',
#  'Census_tract',
#  'Bin',
#  'Bbl',
#  'Nta',
#  'Location_point1']

# %%
isp.head(3)
# Out:
#       CAMIS                                     DBA       BORO  BUILDING  \
# 0  41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1  50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2  50139946                               CHEZ OMAR  Manhattan       394
#
#              STREET  ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0   NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1  STILLWELL AVENUE  11223.0  7182320055                 NaN      01/01/1900
# 2       WEST STREET  10014.0  9175606080                 NaN      01/01/1900
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
#
#                             VIOLATION DESCRIPTION   CRITICAL FLAG  SCORE  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
#
#   GRADE GRADE DATE RECORD DATE                        INSPECTION TYPE  \
# 0   NaN        NaN  11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN  11/12/2023                                    NaN
# 2   NaN        NaN  11/12/2023                                    NaN
#
#     Latitude  Longitude  Community Board  Council District  Census Tract  \
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
#
#          BIN           BBL   NTA  Location Point1
# 0        NaN  4.000000e+00   NaN              NaN
# 1  3176369.0  3.066430e+09  BK29              NaN
# 2  1011975.0  1.006360e+09  MN23              NaN

# %%
isp.columns = new_col_list

# %%
isp.head()
# Out:
#       Camis                                     Dba       Boro  Building  \
# 0  41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1  50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2  50139946                               CHEZ OMAR  Manhattan       394
# 3  50126672                                     NaN          0         2
# 4  50107357                                     NaN     Queens     29-21
#
#               Street  Zipcode       Phone Cuisine_description Inspection_date  \
# 0    NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1   STILLWELL AVENUE  11223.0  7182320055                 NaN      01/01/1900
# 2        WEST STREET  10014.0  9175606080                 NaN      01/01/1900
# 3     SHADY BROOK LN   8512.0  6097997555                 NaN      01/01/1900
# 4  ASTORIA BOULEVARD  11102.0  3478080747                 NaN      01/01/1900
#
#                                             Action Violation_code  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
#
#                             Violation_description   Critical_flag  Score  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
# 3                                             NaN  Not Applicable    NaN
# 4                                             NaN  Not Applicable    NaN
#
#   Grade Grade_date Record_date                        Inspection_type  \
# 0   NaN        NaN  11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN  11/12/2023                                    NaN
# 2   NaN        NaN  11/12/2023                                    NaN
# 3   NaN        NaN  11/12/2023                                    NaN
# 4   NaN        NaN  11/12/2023                                    NaN
#
#     Latitude  Longitude  Community_board  Council_district  Census_tract  \
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
# 3        NaN        NaN              NaN               NaN           NaN
# 4  40.770403 -73.919343            401.0              22.0        6900.0
#
#          Bin           Bbl   Nta  Location_point1
# 0        NaN  4.000000e+00   NaN              NaN
# 1  3176369.0  3.066430e+09  BK29              NaN
# 2  1011975.0  1.006360e+09  MN23              NaN
# 3        NaN           NaN   NaN              NaN
# 4  4017400.0  4.008380e+09  QN71              NaN

# %%
#Value count, Length, and dtype per Column

for col in isp.columns:
    print(f'Column name: {col}')
    print(isp[col].value_counts(dropna=False))
    print("-"*50)
    print("\n")
# Out:
# Column name: Camis
# 40398688    65
# 41406895    59
# 50045647    56
# 40365904    52
# 50111296    49
#             ..
# 50143196     1
# 50109098     1
# 50142808     1
# 50141673     1
# 50108967     1
# Name: Camis, Length: 28320, dtype: int64
# --------------------------------------------------
#
#
# Column name: Dba
# DUNKIN                        2573
# SUBWAY                        1510
# STARBUCKS                     1172
# MCDONALD'S                    1058
# KENNEDY FRIED CHICKEN          707
#                               ...
# GULAABO                          1
# CAFE 58 PIZZERIA AND GRILL       1
# THE GLASSHOUSE ROOFTOP           1
# SHOO LOONG KAN                   1
# 264 suydam LLC                   1
# Name: Dba, Length: 22111, dtype: int64
# --------------------------------------------------
#
#
# Column name: Boro
# Manhattan        77264
# Brooklyn         55682
# Queens           49870
# Bronx            18468
# Staten Island     7163
# 0                   12
# Name: Boro, dtype: int64
# --------------------------------------------------
#
#
# Column name: Building
# 1        1197
# 2         688
# 200       634
# 25        565
# 100       562
#          ...
# 1414        1
# 2853        1
# 2103A       1
# 357A        1
# 2576        1
# Name: Building, Length: 7480, dtype: int64
# --------------------------------------------------
#
#
# Column name: Street
# BROADWAY                   7816
# 3 AVENUE                   4437
# 5 AVENUE                   3591
# 2 AVENUE                   3257
# 8 AVENUE                   2922
#                            ...
# 37th AVENUE                   1
# TENNIS PLACE                  1
# NEWELL STREET                 1
# 6TH AVE                       1
# 65TH STREET TRANSVERVSE       1
# Name: Street, Length: 2403, dtype: int64
# --------------------------------------------------
#
#
# Column name: Zipcode
# 10013.0    4773
# 10003.0    4695
# 10019.0    4096
# 10001.0    3985
# 10036.0    3949
#            ...
# 8512.0        1
# 11003.0       1
# 11550.0       1
# 11518.0       1
# 11021.0       1
# Name: Zipcode, Length: 226, dtype: int64
# --------------------------------------------------
#
#
# Column name: Phone
# 7185958100    274
# 9172843260    144
# 9176186310    142
# 9082308846    122
# 7182246030    117
#              ...
# 6464741557      1
# 6463876550      1
# 3327337040      1
# 9172426968      1
# 3477738412      1
# Name: Phone, Length: 25685, dtype: int64
# --------------------------------------------------
#
#
# Column name: Cuisine_description
# American          34373
# Chinese           20399
# Coffee/Tea        13843
# Pizza             12763
# Latin American     8223
#                   ...
# Armenian             21
# Czech                12
# Basque                9
# Haute Cuisine         5
# Chimichurri           2
# Name: Cuisine_description, Length: 90, dtype: int64
# --------------------------------------------------
#
#
# Column name: Inspection_date
# 01/01/1900    2414
# 04/13/2023     597
# 03/16/2023     585
# 02/16/2023     564
# 04/26/2023     553
#               ...
# 06/30/2021       1
# 05/04/2021       1
# 02/15/2017       1
# 01/09/2019       1
# 04/27/2016       1
# Name: Inspection_date, Length: 1670, dtype: int64
# --------------------------------------------------
#
#
# Column name: Action
# Violations were cited in the following area(s).                                                                                       195148
# Establishment Closed by DOHMH. Violations were cited in the following area(s) and those requiring immediate action were addressed.      7866
# NaN                                                                                                                                     2414
# Establishment re-opened by DOHMH.                                                                                                       1874
# No violations were recorded at the time of this inspection.                                                                             1153
# Establishment re-closed by DOHMH.                                                                                                          4
# Name: Action, dtype: int64
# --------------------------------------------------
#
#
# Column name: Violation_code
# 10F      28652
# 08A      22607
# 06D      14048
# 04L      13840
# 02G      12349
#          ...
# 15-32        1
# 15-29        1
# 20C          1
# 19-01        1
# 19-03        1
# Name: Violation_code, Length: 144, dtype: int64
# --------------------------------------------------
#
#
# Column name: Violation_description
# Non-food contact surface or equipment made of unacceptable material, not kept clean, or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.                                                            16257
# Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.                                                                                                                                     14048
# Establishment is not free of harborage or conditions conducive to rodents, insects or other pests.                                                                                                                                                                                 12982
# Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.    12395
# Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.                                                                                                                                                  9625
#                                                                                                                                                                                                                                                                                    ...
# Organics containers not provided                                                                                                                                                                                                                                                       1
# Document issued by the Board of Health, Commissioner or Department reproduced or altered.  False, untrue or misleading statement or document made to, submitted or filed with the Department                                                                                           1
# Failure to provide a single-use, non-compostable plastic straw upon request.                                                                                                                                                                                                           1
# Non-TCS food that has been served to the public being re-served. (Does not apply to wrapped foods where the wrapper seal has not been broken or opened).                                                                                                                               1
# Failure to post signage in organics collection area.                                                                                                                                                                                                                                   1
# Name: Violation_description, Length: 221, dtype: int64
# --------------------------------------------------
#
#
# Column name: Critical_flag
# Critical          113437
# Not Critical       90176
# Not Applicable      4846
# Name: Critical_flag, dtype: int64
# --------------------------------------------------
#
#
# Column name: Score
# 12.0     17314
# 13.0     15526
# NaN       9870
# 0.0       9840
# 10.0      8711
#          ...
# 168.0        9
# 142.0        8
# 112.0        8
# 110.0        8
# 140.0        5
# Name: Score, Length: 131, dtype: int64
# --------------------------------------------------
#
#
# Column name: Grade
# NaN    106331
# A       70938
# B       11370
# N        8640
# C        6684
# Z        3929
# P         567
# Name: Grade, dtype: int64
# --------------------------------------------------
#
#
# Column name: Grade_date
# NaN           114954
# 12/01/2022       350
# 02/28/2023       336
# 02/27/2023       333
# 03/01/2023       331
#                ...
# 04/23/2022         1
# 12/18/2016         1
# 05/19/2018         1
# 06/04/2016         1
# 04/27/2016         1
# Name: Grade_date, Length: 1447, dtype: int64
# --------------------------------------------------
#
#
# Column name: Record_date
# 11/12/2023    208459
# Name: Record_date, dtype: int64
# --------------------------------------------------
#
#
# Column name: Inspection_type
# Cycle Inspection / Initial Inspection                          113068
# Cycle Inspection / Re-inspection                                36925
# Pre-permit (Operational) / Initial Inspection                   31084
# Pre-permit (Operational) / Re-inspection                         9622
# Administrative Miscellaneous / Initial Inspection                4903
# Pre-permit (Non-operational) / Initial Inspection                2605
# NaN                                                              2414
# Pre-permit (Operational) / Compliance Inspection                 1634
# Cycle Inspection / Reopening Inspection                          1408
# Administrative Miscellaneous / Re-inspection                      973
# Pre-permit (Operational) / Reopening Inspection                   741
# Cycle Inspection / Compliance Inspection                          741
# Smoke-Free Air Act / Initial Inspection                           549
# Trans Fat / Initial Inspection                                    380
# Calorie Posting / Initial Inspection                              327
# Inter-Agency Task Force / Initial Inspection                      319
# Pre-permit (Operational) / Second Compliance Inspection           199
# Pre-permit (Non-operational) / Re-inspection                      190
# Administrative Miscellaneous / Compliance Inspection               98
# Trans Fat / Re-inspection                                          63
# Calorie Posting / Re-inspection                                    52
# Smoke-Free Air Act / Re-inspection                                 47
# Administrative Miscellaneous / Reopening Inspection                42
# Cycle Inspection / Second Compliance Inspection                    33
# Pre-permit (Non-operational) / Compliance Inspection               17
# Administrative Miscellaneous / Second Compliance Inspection         8
# Smoke-Free Air Act / Limited Inspection                             7
# Smoke-Free Air Act / Compliance Inspection                          4
# Trans Fat / Compliance Inspection                                   2
# Pre-permit (Non-operational) / Second Compliance Inspection         2
# Calorie Posting / Compliance Inspection                             1
# Inter-Agency Task Force / Re-inspection                             1
# Name: Inspection_type, dtype: int64
# --------------------------------------------------
#
#
# Column name: Latitude
# 0.000000     2677
# 40.648313     601
# 40.733840     302
# NaN           261
# 40.582297     260
#              ...
# 40.705175       1
# 40.657338       1
# 40.720001       1
# 40.735876       1
# 40.702253       1
# Name: Latitude, Length: 23150, dtype: int64
# --------------------------------------------------
#
#
# Column name: Longitude
#  0.000000     2677
# -73.788281     601
# -73.871577     302
#  NaN           261
# -74.169053     260
#               ...
# -73.925232       1
# -74.006437       1
# -73.987464       1
# -73.936622       1
# -73.923577       1
# Name: Longitude, Length: 23150, dtype: int64
# --------------------------------------------------
#
#
# Column name: Community_board
# 105.0    15228
# 103.0    10439
# 102.0     9579
# 104.0     7994
# 407.0     7788
#          ...
# 355.0       43
# 164.0       34
# 226.0        9
# 595.0        5
# 482.0        4
# Name: Community_board, Length: 70, dtype: int64
# --------------------------------------------------
#
#
# Column name: Council_district
# 3.0     16810
# 1.0     15354
# 4.0     13664
# 2.0     10923
# 33.0     6525
# 20.0     6201
# 26.0     6126
# 34.0     5881
# 39.0     5407
# 43.0     4792
# 22.0     4630
# 35.0     4493
# 38.0     4451
# 6.0      4374
# 5.0      4160
# 25.0     4114
# 21.0     3907
# 19.0     3454
# 29.0     3256
# 10.0     3255
# NaN      3232
# 7.0      3193
# 40.0     3102
# 8.0      3045
# 36.0     3033
# 47.0     2992
# 37.0     2855
# 28.0     2774
# 48.0     2773
# 32.0     2687
# 30.0     2565
# 13.0     2562
# 49.0     2556
# 50.0     2482
# 24.0     2431
# 11.0     2430
# 15.0     2427
# 17.0     2395
# 27.0     2368
# 45.0     2349
# 46.0     2253
# 23.0     2159
# 9.0      2155
# 51.0     2148
# 41.0     2091
# 18.0     1982
# 16.0     1763
# 44.0     1733
# 12.0     1728
# 14.0     1683
# 42.0     1399
# 31.0     1337
# Name: Council_district, dtype: int64
# --------------------------------------------------
#
#
# Column name: Census_tract
# NaN         3232
# 87100.0     1848
# 6500.0      1612
# 4100.0      1593
# 2900.0      1533
#             ...
# 1001.0         1
# 144100.0       1
# 61002.0        1
# 81000.0        1
# 93900.0        1
# Name: Census_tract, Length: 1185, dtype: int64
# --------------------------------------------------
#
#
# Column name: Bin
# NaN          4207
# 4000000.0    1090
# 1000000.0     445
# 3000000.0     356
# 4045999.0     319
#              ...
# 1007475.0       1
# 5052860.0       1
# 4442970.0       1
# 4079997.0       1
# 3335892.0       1
# Name: Bin, Length: 20054, dtype: int64
# --------------------------------------------------
#
#
# Column name: Bbl
# 1.000000e+00    1692
# 4.000000e+00    1032
# NaN              551
# 3.000000e+00     493
# 4.142600e+09     461
#                 ...
# 4.079840e+09       1
# 4.000000e+09       1
# 3.066080e+09       1
# 4.061480e+09       1
# 3.001280e+09       1
# Name: Bbl, Length: 19744, dtype: int64
# --------------------------------------------------
#
#
# Column name: Nta
# MN17    11371
# MN13     5965
# MN23     5893
# MN24     5873
# MN27     4793
#         ...
# MN50       82
# BK93       72
# SI08       64
# MN99       58
# SI48       30
# Name: Nta, Length: 194, dtype: int64
# --------------------------------------------------
#
#
# Column name: Location_point1
# NaN    208459
# Name: Location_point1, dtype: int64
# --------------------------------------------------

# %% [markdown]
# # Assumptions Thus Far
# - TBD
# - TBD

# %% [markdown]
# ## Initial Exploration Questions

# %% [markdown]
# * Drop the Location_point1 column, all NaN
# * Potentially drop record pull date (same value for entire data set.)
# * Why are there 112954 NaN for Grade Date?
# * Why do Zip Codes have a float on them?
# * What is Borough 0?
# * 2414 Restaurants not yet inspected (INT 64 ) - can change to 00/00/0000
# * Columns Bbl, Nta, Bin, and Census_tract require further investigation (unsure of what they represent)

# %% [markdown]
# ### Data Cleaning
#
# Change the name of some columns to be more readable

# %%
isp.rename(columns={'Dba': 'Restaurant_name'}, inplace=True)

# %%
isp.rename(columns={'Boro': 'Borough'}, inplace= True)

# %%
isp.head()
# Out:
#       Camis                         Restaurant_name    Borough  Building  \
# 0  41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1  50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2  50139946                               CHEZ OMAR  Manhattan       394
# 3  50126672                                     NaN          0         2
# 4  50107357                                     NaN     Queens     29-21
#
#               Street  Zipcode       Phone Cuisine_description Inspection_date  \
# 0    NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1   STILLWELL AVENUE  11223.0  7182320055                 NaN      01/01/1900
# 2        WEST STREET  10014.0  9175606080                 NaN      01/01/1900
# 3     SHADY BROOK LN   8512.0  6097997555                 NaN      01/01/1900
# 4  ASTORIA BOULEVARD  11102.0  3478080747                 NaN      01/01/1900
#
#                                             Action Violation_code  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
#
#                             Violation_description   Critical_flag  Score  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
# 3                                             NaN  Not Applicable    NaN
# 4                                             NaN  Not Applicable    NaN
#
#   Grade Grade_date Record_date                        Inspection_type  \
# 0   NaN        NaN  11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN  11/12/2023                                    NaN
# 2   NaN        NaN  11/12/2023                                    NaN
# 3   NaN        NaN  11/12/2023                                    NaN
# 4   NaN        NaN  11/12/2023                                    NaN
#
#     Latitude  Longitude  Community_board  Council_district  Census_tract  \
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
# 3        NaN        NaN              NaN               NaN           NaN
# 4  40.770403 -73.919343            401.0              22.0        6900.0
#
#          Bin           Bbl   Nta  Location_point1
# 0        NaN  4.000000e+00   NaN              NaN
# 1  3176369.0  3.066430e+09  BK29              NaN
# 2  1011975.0  1.006360e+09  MN23              NaN
# 3        NaN           NaN   NaN              NaN
# 4  4017400.0  4.008380e+09  QN71              NaN

# %%
isp.rename(columns={'Camis': 'Record_id','Record_date': 'Date_of_data_pull', }, inplace=True)

# %%
#Check for and drop any duplicate rows
print('length before drop:', len(isp))

isp = isp.drop_duplicates()

print('length after drop:', len(isp))
# Out:
# length before drop: 208459
# length after drop: 208453

# %% [markdown]
# * No duplicates

# %% [markdown]
# * Drop the Location_point1 column, all NaN
# * Potentially drop record pull date (same value for entire data set.)
# * Why are there 112954 NaN for Grade Date?
# * Why do Zip Codes have a float on them?
# * What is Borough 0?
# * 2414 Restaurants not yet inspected (INT 64 ) - can change to 00/00/0000
# * Columns Bbl, Nta, Bin, and Census_tract require further investigation (unsure of what they represent)

# %%
#Replace 01/01/1900 (Proxy used for not yet inspected restaurants) with 00/00/0000 (easier to identify as not a real date)
# old = '01/01/1900'
# new = '00/00/0000'
# isp['Inspection_date'] = isp['Inspection_date'].replace(old,new)
# isp['Inspection_date'] = isp['Inspection_date'].replace(new, old)

# %%
isp['Inspection_date'].value_counts()
# Out:
# 01/01/1900    2414
# 04/13/2023     597
# 03/16/2023     585
# 02/16/2023     564
# 04/26/2023     553
#               ...
# 06/30/2021       1
# 05/04/2021       1
# 02/15/2017       1
# 01/09/2019       1
# 04/27/2016       1
# Name: Inspection_date, Length: 1670, dtype: int64

# %%
isp['Inspection_date'] = pd.to_datetime(isp['Inspection_date'], format = '%m/%d/%Y')
isp['Inspection_date'].sort_values(ascending = False)

dates = pd.DataFrame(isp['Inspection_date'].value_counts())
dates.reset_index(inplace = True)
dates = dates.sort_values(by = 'index', ascending = False)
dates = dates.loc[(dates['index'] > '1900-01-01')]
dates
# Out:
#           index  Inspection_date
# 503  2023-11-09              166
# 500  2023-11-08              167
# 354  2023-11-06              293
# 512  2023-11-03              159
# 143  2023-11-02              416
# ...         ...              ...
# 1307 2015-11-20                4
# 1526 2015-11-19                2
# 1649 2015-10-15                1
# 1473 2015-10-14                2
# 1208 2015-09-24                5
#
# [1669 rows x 2 columns]

# %%
plt.plot(dates['index'], dates['Inspection_date'])
plt.xlabel("Date of inspection")
plt.ylabel("Number of inspections")
plt.title('Inspection date by frequency')
# Out:
# Text(0.5, 1.0, 'Inspection date by frequency')

# %%
drop_col= 'Location_point1' 
isp = isp.drop(drop_col, axis=1)

# %%
isp.head()
# Out:
#    Record_id                         Restaurant_name    Borough  Building  \
# 0   41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1   50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2   50139946                               CHEZ OMAR  Manhattan       394
# 3   50126672                                     NaN          0         2
# 4   50107357                                     NaN     Queens     29-21
#
#               Street  Zipcode       Phone Cuisine_description Inspection_date  \
# 0    NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1   STILLWELL AVENUE  11223.0  7182320055                 NaN      00/00/0000
# 2        WEST STREET  10014.0  9175606080                 NaN      00/00/0000
# 3     SHADY BROOK LN   8512.0  6097997555                 NaN      00/00/0000
# 4  ASTORIA BOULEVARD  11102.0  3478080747                 NaN      00/00/0000
#
#                                             Action Violation_code  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
#
#                             Violation_description   Critical_flag  Score  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
# 3                                             NaN  Not Applicable    NaN
# 4                                             NaN  Not Applicable    NaN
#
#   Grade Grade_date Date_of_data_pull                        Inspection_type  \
# 0   NaN        NaN        11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN        11/12/2023                                    NaN
# 2   NaN        NaN        11/12/2023                                    NaN
# 3   NaN        NaN        11/12/2023                                    NaN
# 4   NaN        NaN        11/12/2023                                    NaN
#
#     Latitude  Longitude  Community_board  Council_district  Census_tract  \
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
# 3        NaN        NaN              NaN               NaN           NaN
# 4  40.770403 -73.919343            401.0              22.0        6900.0
#
#          Bin           Bbl   Nta
# 0        NaN  4.000000e+00   NaN
# 1  3176369.0  3.066430e+09  BK29
# 2  1011975.0  1.006360e+09  MN23
# 3        NaN           NaN   NaN
# 4  4017400.0  4.008380e+09  QN71

# %%
isp['Restaurant_name'].describe()
# Out:
# count     207866
# unique     22110
# top       DUNKIN
# freq        2573
# Name: Restaurant_name, dtype: object

# %%
# check NaN restaurant names
isp['Restaurant_name'].isna().sum()
# Out:
# 587

# %%
# See what other columns have a NaN if Rest Name is a NaN
# Use a boolean mask where True represents NaN values and apply to DF to get subset of rows which have NaN values
isp[isp['Restaurant_name'].isna()]
# Out:
#         Record_id Restaurant_name        Borough Building  \
# 3        50126672             NaN              0        2
# 4        50107357             NaN         Queens    29-21
# 5        50140007             NaN      Manhattan     1154
# 6        50131153             NaN         Queens    13621
# 10       50143471             NaN          Bronx      812
# ...           ...             ...            ...      ...
# 205697   50132784             NaN          Bronx      283
# 206395   50129735             NaN      Manhattan     1802
# 206422   50125471             NaN       Brooklyn      228
# 206915   50144191             NaN  Staten Island     2636
# 207418   50142565             NaN  Staten Island      451
#
#                          Street  Zipcode       Phone Cuisine_description  \
# 3                SHADY BROOK LN   8512.0  6097997555                 NaN
# 4             ASTORIA BOULEVARD  11102.0  3478080747                 NaN
# 5                      1 AVENUE  10065.0  9176925975                 NaN
# 6                 ROOSEVELT AVE  11354.0  9299908888                 NaN
# 10                    RIVER AVE  10451.0  6508042797                 NaN
# ...                         ...      ...         ...                 ...
# 205697        SAINT ANNS AVENUE  10454.0  9176881611             Spanish
# 206395  65TH STREET TRANSVERVSE      NaN  9172151616                 NaN
# 206422          DUFFIELD STREET  11201.0  9175159593                 NaN
# 206915          HYLAN BOULEVARD  10306.0  3477015000                 NaN
# 207418        NORTHFIELD AVENUE  10303.0  3479895463                 NaN
#
#        Inspection_date                                           Action  \
# 3           00/00/0000                                              NaN
# 4           00/00/0000                                              NaN
# 5           00/00/0000                                              NaN
# 6           00/00/0000                                              NaN
# 10          00/00/0000                                              NaN
# ...                ...                                              ...
# 205697      08/10/2023  Violations were cited in the following area(s).
# 206395      00/00/0000                                              NaN
# 206422      00/00/0000                                              NaN
# 206915      00/00/0000                                              NaN
# 207418      00/00/0000                                              NaN
#
#        Violation_code                              Violation_description  \
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 6                 NaN                                                NaN
# 10                NaN                                                NaN
# ...               ...                                                ...
# 205697            10F  Non-food contact surface or equipment made of ...
# 206395            NaN                                                NaN
# 206422            NaN                                                NaN
# 206915            NaN                                                NaN
# 207418            NaN                                                NaN
#
#          Critical_flag  Score Grade Grade_date Date_of_data_pull  \
# 3       Not Applicable    NaN   NaN        NaN        11/12/2023
# 4       Not Applicable    NaN   NaN        NaN        11/12/2023
# 5       Not Applicable    NaN   NaN        NaN        11/12/2023
# 6       Not Applicable    NaN   NaN        NaN        11/12/2023
# 10      Not Applicable    NaN   NaN        NaN        11/12/2023
# ...                ...    ...   ...        ...               ...
# 205697    Not Critical   27.0     N        NaN        11/12/2023
# 206395  Not Applicable    NaN   NaN        NaN        11/12/2023
# 206422  Not Applicable    NaN   NaN        NaN        11/12/2023
# 206915  Not Applicable    NaN   NaN        NaN        11/12/2023
# 207418  Not Applicable    NaN   NaN        NaN        11/12/2023
#
#                                       Inspection_type   Latitude  Longitude  \
# 3                                                 NaN        NaN        NaN
# 4                                                 NaN  40.770403 -73.919343
# 5                                                 NaN  40.762302 -73.959985
# 6                                                 NaN  40.759792 -73.829243
# 10                                                NaN  40.826132 -73.926895
# ...                                               ...        ...        ...
# 205697  Pre-permit (Operational) / Initial Inspection  40.807919 -73.916743
# 206395                                            NaN   0.000000   0.000000
# 206422                                            NaN  40.691298 -73.984393
# 206915                                            NaN  40.567454 -74.112765
# 207418                                            NaN  40.628323 -74.168654
#
#         Community_board  Council_district  Census_tract        Bin  \
# 3                   NaN               NaN           NaN        NaN
# 4                 401.0              22.0        6900.0  4017400.0
# 5                 108.0               5.0       10602.0  1072681.0
# 6                 407.0              20.0       87100.0  4112492.0
# 10                204.0              16.0        6300.0        NaN
# ...                 ...               ...           ...        ...
# 205697            201.0               8.0        3900.0  2000082.0
# 206395              NaN               NaN           NaN        NaN
# 206422            302.0              33.0        1500.0  3424452.0
# 206915            502.0              50.0       12804.0  5000000.0
# 207418            501.0              49.0       32300.0  5169471.0
#
#                  Bbl   Nta
# 3                NaN   NaN
# 4       4.008380e+09  QN71
# 5       1.014588e+09  MN31
# 6       4.049800e+09  QN22
# 10      2.000000e+00  BX63
# ...              ...   ...
# 205697  2.022670e+09  BX39
# 206395  1.000000e+00   NaN
# 206422  3.001450e+09  BK38
# 206915  5.039690e+09  SI45
# 207418  5.012700e+09  SI12
#
# [587 rows x 26 columns]

# %%
isp.head()
# Out:
#    Record_id                         Restaurant_name    Borough  Building  \
# 0   41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1   50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2   50139946                               CHEZ OMAR  Manhattan       394
# 3   50126672                                     NaN          0         2
# 4   50107357                                     NaN     Queens     29-21
#
#               Street  Zipcode       Phone Cuisine_description Inspection_date  \
# 0    NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1   STILLWELL AVENUE  11223.0  7182320055                 NaN      00/00/0000
# 2        WEST STREET  10014.0  9175606080                 NaN      00/00/0000
# 3     SHADY BROOK LN   8512.0  6097997555                 NaN      00/00/0000
# 4  ASTORIA BOULEVARD  11102.0  3478080747                 NaN      00/00/0000
#
#                                             Action Violation_code  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
#
#                             Violation_description   Critical_flag  Score  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
# 3                                             NaN  Not Applicable    NaN
# 4                                             NaN  Not Applicable    NaN
#
#   Grade Grade_date Date_of_data_pull                        Inspection_type  \
# 0   NaN        NaN        11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN        11/12/2023                                    NaN
# 2   NaN        NaN        11/12/2023                                    NaN
# 3   NaN        NaN        11/12/2023                                    NaN
# 4   NaN        NaN        11/12/2023                                    NaN
#
#     Latitude  Longitude  Community_board  Council_district  Census_tract
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
# 3        NaN        NaN              NaN               NaN           NaN
# 4  40.770403 -73.919343            401.0              22.0        6900.0

# %% [markdown]
# * Appears some of these Inspections were pre-permit (Operational) which may explain the lack of name. Many others we may need to exclude for additional analysis

# %% [markdown]
# ### Notes on Grades Column
# * N= Not Yet Graded
# * A = Grade A
# * B = Grade B
# * C = Grade C
# * Z = Grade Pending
# * P=Grade Pending issued on re-opening following an initial inspection that resulted in a closure

# %%
#Dropping Columns which seem to be statistical methods used for someone else's analysis
drop_cols = ['Bin','Bbl','Nta']
isp.drop(drop_cols, axis=1, inplace=True)

# %%
isp.columns
# Out:
# Index(['Record_id', 'Restaurant_name', 'Borough', 'Building', 'Street',
#        'Zipcode', 'Phone', 'Cuisine_description', 'Inspection_date', 'Action',
#        'Violation_code', 'Violation_description', 'Critical_flag', 'Score',
#        'Grade', 'Grade_date', 'Date_of_data_pull', 'Inspection_type',
#        'Latitude', 'Longitude', 'Community_board', 'Council_district',
#        'Census_tract'],
#       dtype='object')

# %%
isp.head()
# Out:
#    Record_id                         Restaurant_name    Borough  Building  \
# 0   41503108                     TULCINGO RESTAURANT     Queens  40364040
# 1   50135598  United Chinese Association of Brooklyn   Brooklyn      1787
# 2   50139946                               CHEZ OMAR  Manhattan       394
# 3   50126672                                     NaN          0         2
# 4   50107357                                     NaN     Queens     29-21
#
#               Street  Zipcode       Phone Cuisine_description Inspection_date  \
# 0    NATIONAL STREET      NaN  7186398880             Mexican      09/26/2023
# 1   STILLWELL AVENUE  11223.0  7182320055                 NaN      00/00/0000
# 2        WEST STREET  10014.0  9175606080                 NaN      00/00/0000
# 3     SHADY BROOK LN   8512.0  6097997555                 NaN      00/00/0000
# 4  ASTORIA BOULEVARD  11102.0  3478080747                 NaN      00/00/0000
#
#                                             Action Violation_code  \
# 0  Violations were cited in the following area(s).            02B
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
#
#                             Violation_description   Critical_flag  Score  \
# 0  Hot TCS food item not held at or above 140 °F.        Critical   26.0
# 1                                             NaN  Not Applicable    NaN
# 2                                             NaN  Not Applicable    NaN
# 3                                             NaN  Not Applicable    NaN
# 4                                             NaN  Not Applicable    NaN
#
#   Grade Grade_date Date_of_data_pull                        Inspection_type  \
# 0   NaN        NaN        11/12/2023  Cycle Inspection / Initial Inspection
# 1   NaN        NaN        11/12/2023                                    NaN
# 2   NaN        NaN        11/12/2023                                    NaN
# 3   NaN        NaN        11/12/2023                                    NaN
# 4   NaN        NaN        11/12/2023                                    NaN
#
#     Latitude  Longitude  Community_board  Council_district  Census_tract
# 0   0.000000   0.000000              NaN               NaN           NaN
# 1  40.602887 -73.986424            311.0              43.0       40400.0
# 2  40.733028 -74.010284            102.0               3.0        7500.0
# 3        NaN        NaN              NaN               NaN           NaN
# 4  40.770403 -73.919343            401.0              22.0        6900.0

# %%
isp.to_csv("NYC_Inspections_stage1_cleaned.csv",index=False)
